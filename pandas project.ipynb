# %%
import pandas as pd
pay=pd.read_csv('C:\\Users\\tahmi\\OneDrive\\Desktop\\2023-08-16T16-46-18.477Z-City_of_Chicago_Payroll_Data.csv')
pay
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN    $107790.00
# ...

# %%
print('max is:',pay['Typical Hours'].max())
print('min is:',pay['Typical Hours'].min())
print('mean is:',pay['Typical Hours'].mean())
# Out:
# max is: 40.0
# min is: 10.0
# mean is: 34.69871876189268

# %%
import pandas as pd
pay=pd.read_csv('C:\\Users\\tahmi\\OneDrive\\Desktop\\2023-08-16T16-46-18.477Z-City_of_Chicago_Payroll_Data.csv')
x=pay.groupby('Salary or Hourly')[['Name']].count()
print(x)
y=pay['Salary or Hourly'].value_counts()
y
# Out:
#                    Name
# Salary or Hourly
# Hourly             7883
# Salary            24775
# Salary or Hourly
# Salary    24775
# Hourly     7883
# Name: count, dtype: int64

# %%
print(pay['Department'].value_counts())
# Out:
# Department
# POLICE                   12973
# FIRE                      4800
# STREETS & SAN             2194
# OEMC                      2044
# WATER MGMNT               1878
# AVIATION                  1612
# TRANSPORTN                1103
# GENERAL SERVICES           972
# PUBLIC LIBRARY             932
# FAMILY & SUPPORT           621
# FINANCE                    575
# HEALTH                     516
# LAW                        405
# CITY COUNCIL               400
# BUILDINGS                  266
# COMMUNITY DEVELOPMENT      214
# BUSINESS AFFAIRS           168
# BOARD OF ELECTION          112
# DoIT                       101
# PROCUREMENT                 86
# MAYOR'S OFFICE              85
# CITY CLERK                  85
# CULTURAL AFFAIRS            76
# ANIMAL CONTRL               73
# HUMAN RESOURCES             68
# INSPECTOR GEN               63
# IPRA                        56
# BUDGET & MGMT               44
# ADMIN HEARNG                38
# ...

# %%
 pay[pay['Department']=='POLICE'].groupby('Salary or Hourly').count()[['Name']]
# Out:
#                    Name
# Salary or Hourly
# Hourly               32
# Salary            12941

# %%
import pandas as pd
pay=pd.read_csv('C:\\Users\\tahmi\\OneDrive\\Desktop\\2023-08-16T16-46-18.477Z-City_of_Chicago_Payroll_Data.csv')
pay['asalary']=pay['Annual Salary'].str.replace('$','').astype(float)
print(pay)
print(pay['asalary'].max())
pay.loc[pay['asalary'].idxmax()][['Name']]
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN    $107790.00
# ...

# %%
pay[pay['asalary']==pay['asalary'].max()][['Name']]
# Out:
#                   Name
# 8310  EVANS,  GINGER S
