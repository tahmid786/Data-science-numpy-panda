# %%
import numpy as np
import pandas as pd
dates=pd.date_range('1/1/2000',periods=500)
dates
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2001-05-05', '2001-05-06', '2001-05-07', '2001-05-08',
#                '2001-05-09', '2001-05-10', '2001-05-11', '2001-05-12',
#                '2001-05-13', '2001-05-14'],
#               dtype='datetime64[ns]', length=500, freq='D')

# %%
data1=np.random.rand(500,3)
data1
# Out:
# array([[0.92373354, 0.5472212 , 0.50204415],
#        [0.86964478, 0.6878029 , 0.19132079],
#        [0.46927395, 0.78012811, 0.06459123],
#        ...,
#        [0.10644752, 0.6813256 , 0.78464674],
#        [0.72483777, 0.58709438, 0.65364473],
#        [0.65153707, 0.51278   , 0.2577617 ]])

# %%
df1=pd.DataFrame(data=data1,index=dates,columns=['A','B','c'])
df1
# Out:
#                    A         B         c
# 2000-01-01  0.923734  0.547221  0.502044
# 2000-01-02  0.869645  0.687803  0.191321
# 2000-01-03  0.469274  0.780128  0.064591
# 2000-01-04  0.389001  0.819214  0.220834
# 2000-01-05  0.245655  0.953424  0.216740
# ...              ...       ...       ...
# 2001-05-10  0.186084  0.360042  0.674162
# 2001-05-11  0.430458  0.839124  0.180187
# 2001-05-12  0.106448  0.681326  0.784647
# 2001-05-13  0.724838  0.587094  0.653645
# 2001-05-14  0.651537  0.512780  0.257762
#
# [500 rows x 3 columns]

# %%
df1['D']=np.random.rand(500)
df1
# Out:
#                    A         B         c         D
# 2000-01-01  0.923734  0.547221  0.502044  0.646786
# 2000-01-02  0.869645  0.687803  0.191321  0.226539
# 2000-01-03  0.469274  0.780128  0.064591  0.159807
# 2000-01-04  0.389001  0.819214  0.220834  0.895214
# 2000-01-05  0.245655  0.953424  0.216740  0.338201
# ...              ...       ...       ...       ...
# 2001-05-10  0.186084  0.360042  0.674162  0.576622
# 2001-05-11  0.430458  0.839124  0.180187  0.494979
# 2001-05-12  0.106448  0.681326  0.784647  0.586784
# 2001-05-13  0.724838  0.587094  0.653645  0.628929
# 2001-05-14  0.651537  0.512780  0.257762  0.107502
#
# [500 rows x 4 columns]

# %%
data2=np.random.rand(20,3)
col=['X','Y','Z']
df2=pd.DataFrame(data=data2,columns=col)
df2
# Out:
#            X         Y         Z
# 0   0.972267  0.050407  0.274229
# 1   0.082613  0.446774  0.467861
# 2   0.523173  0.870535  0.414166
# 3   0.421064  0.517971  0.196012
# 4   0.964688  0.429701  0.498421
# 5   0.753741  0.867880  0.780711
# 6   0.609758  0.445652  0.112373
# 7   0.771032  0.266867  0.934055
# 8   0.755109  0.489899  0.597411
# 9   0.994405  0.986034  0.489690
# 10  0.073913  0.516825  0.151554
# 11  0.780167  0.017274  0.042748
# 12  0.540133  0.803083  0.311783
# 13  0.546596  0.993251  0.071851
# 14  0.994760  0.650968  0.540344
# 15  0.329169  0.710749  0.612818
# 16  0.359545  0.057160  0.264857
# 17  0.174818  0.924133  0.974095
# 18  0.701943  0.206056  0.076728
# 19  0.684717  0.567856  0.060122

# %%
df1['A'].hist(bins=50) #koto vage vag hobe histogram
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')#declare r por ei style e sob graph ready hobe
df1['A'].hist(bins=100)
# Out:
# <Axes: >

# %%
plt.style.use('bmh')#declare r por ei style e sob graph ready hobe
df1['A'].hist(bins=150)
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')#declare r por ei style e sob graph ready hobe
df1['A'].hist(bins=70)
# Out:
# <Axes: >

# %%
df2['X'].plot()
# Out:
# <Axes: >

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2.plot.area() #stack kore dey
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(15,5))
df2.plot.barh(figsize=(15,5))#horizontal
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True,figsize=(15,5))
# Out:
# <Axes: >

# %%
fifa = pd.read_csv(r"D:\2023-08-30T16-51-37.825Z-fifa_data.csv")
fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
plt.subplots(figsize=(10,5))
plt.plot(fifa['Overall'],fifa['Age'])
plt.show()

# %%
fifa.Club[::1000].tolist()
# Out:
# ['FC Barcelona',
#  'Bologna',
#  'Norwich City',
#  'Cardiff City',
#  'Sporting Lokeren',
#  'U.N.A.M.',
#  'FC Barcelona',
#  'FC Würzburger Kickers',
#  'Lecce',
#  'DC United',
#  'Stoke City',
#  'Zagłębie Lubin',
#  'Changchun Yatai FC',
#  "CD O'Higgins",
#  'San Jose Earthquakes',
#  'Gangwon FC',
#  'Fulham',
#  'SV Mattersburg',
#  'Miedź Legnica']

# %%
import pandas as pd
import matplotlib.pyplot as plt

fifa = pd.read_csv(r"D:\2023-08-30T16-51-37.825Z-fifa_data.csv")

plt.figure(figsize=(10, 5))
plt.plot(fifa['Overall'], fifa['Age'])
my_array = np.arange(40, 101,5)
plt.xticks(my_array)

plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(fifa['Age'], fifa['Overall'],'yo',label='Overall')
plt.plot(fifa['Age'], fifa['Potential'],'g+',label='Potential')
my_array1 = np.arange(40, 101,5)
plt.xticks(my_array2)
my_array2=np.arange(15, 45,3)
plt.yticks(my_array1)
plt.legend()

# %%
#bubble chart
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)
df = pd.DataFrame(np.random.rand(1000, 4), columns=['a', 'b', 'c', 'd'])


total_entries = df.shape[0]

print(f'Total entries: {total_entries}')
# Out:
# Total entries: 1000
